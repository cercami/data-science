# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_csv("/home/scott/Documents/kaggle_data/ClickFraud/train.csv")

# %%
df = pd.read_csv("/home/scott/Documents/GIT/data-science/kaggle/ClickFraud_detection/train_sample.csv")
'''
ip: ip address of click.
app: app id for marketing.
device: device type id of user mobile phone (e.g., iphone 6 plus, iphone 7, huawei mate 7, etc.)
os: os version id of user mobile phone
channel: channel id of mobile ad publisher
click_time: timestamp of click (UTC)
attributed_time: if user download the app for after clicking an ad, this is the time of the app download
is_attributed: the target that is to be predicted, indicating the app was downloaded
'''

# %%
# From my personal knowledge about fraudelent clicks, I know that:
# fraudulent clicks happen more at night
# bots take over older OS versions

df[df.is_attributed == 1].describe()
# Out:
#                   ip         app      device          os     channel  \
# count     227.000000  227.000000  227.000000  227.000000  227.000000
# mean   171715.154185   32.229075   17.986784   30.070485  205.365639
# std    106667.455804   33.769395   89.035564   93.414692  117.758991
# min      2948.000000    3.000000    0.000000    0.000000    3.000000
# 25%     81155.000000   18.000000    1.000000   13.000000  113.000000
# 50%    179080.000000   19.000000    1.000000   19.000000  213.000000
# 75%    256782.500000   35.000000    1.000000   24.000000  274.000000
# max    358438.000000  261.000000  957.000000  866.000000  489.000000
#
#        is_attributed
# count          227.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
df.click_time = pd.to_datetime(df.click_time)
df['hour'] = df.click_time.apply(lambda x: x.hour)

# %%
df.groupby('hour').count()['ip']
# Out:
# hour
# 0     5654
# 1     5103
# 2     5137
# 3     5264
# 4     6039
# 5     5400
# 6     5079
# 7     5089
# 8     4576
# 9     4867
# 10    5511
# 11    5342
# 12    5326
# 13    5619
# 14    5561
# 15    4957
# 16    3812
# 17    2176
# 18    1183
# 19     870
# 20     699
# 21     864
# 22    2002
# 23    3870
# Name: ip, dtype: int64

# %%
plt.plot(df.groupby('hour').count()['ip'])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.figure()
plt.plot(df[df.is_attributed == 1].groupby('hour').count()['ip'])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
df.groupby('os').
# Out:
#            ip  app  device  os  channel          click_time attributed_time  \
# 0       87540   12       1  13      497 2017-11-07 09:30:38             NaN
# 1      105560   25       1  17      259 2017-11-07 13:40:27             NaN
# 2      101424   12       1  19      212 2017-11-07 18:05:24             NaN
# 3       94584   13       1  13      477 2017-11-07 04:58:08             NaN
# 4       68413   12       1   1      178 2017-11-09 09:00:09             NaN
# 5       93663    3       1  17      115 2017-11-09 01:22:13             NaN
# 6       17059    1       1  17      135 2017-11-09 01:17:58             NaN
# 7      121505    9       1  25      442 2017-11-07 10:01:53             NaN
# 8      192967    2       2  22      364 2017-11-08 09:35:17             NaN
# 9      143636    3       1  19      135 2017-11-08 12:35:26             NaN
# 10      73839    3       1  22      489 2017-11-08 08:14:37             NaN
# ...
