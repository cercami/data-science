# %%
df = pd.read_csv("/home/scott/Documents/GIT/data-science/crim_pris_age.tsv", sep="\t")

# %%
df['split'] = df[df.columns[0]].str.split(",")

# %%
df
# Out:
#      age,sex,unit,geo\time    2015     2014     2013     2012     2011   \
# 0            ADULT,F,NR,AL     121      109       89       82       84
# 1            ADULT,F,NR,AT     498      501      538      568      564
# 2            ADULT,F,NR,BA      86       60       56        :       38
# 3            ADULT,F,NR,BE     525        :      456      440      437
# 4            ADULT,F,NR,BG     245      258      263      307      289
# 5            ADULT,F,NR,CH     355      315      347      306      301
# 6            ADULT,F,NR,CY      31       30       25       43       35
# 7            ADULT,F,NR,CZ    1430     1164      954     1446     1480
# 8            ADULT,F,NR,DE    3609     3639     3797     3943     3927
# 9            ADULT,F,NR,DK     118      145      189      149      164
# 10           ADULT,F,NR,EE     153        :      154      162      181
# 11           ADULT,F,NR,EL     488      561      648      557      562
# ...
