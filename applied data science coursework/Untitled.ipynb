# %%
import requests
from bs4 import BeautifulSoup

# Let's now pull the average monthy daytime temperatures from wikipedia
r = requests.get("https://en.wikipedia.org/wiki/Berlin#Climate")
soup = BeautifulSoup(r.text, "lxml")
#table = soup.find("th", text="Climate data for Berlin- Tempelhof (1971–2000), extremes (1876– 2015) (Source: DWD)")

table = soup.findAll("table", {"class" : "wikitable collapsible"})[0]

df = pd.read_html(str(table), skiprows=1, index_col=0)[0]

df.columns = df.loc['Month'].tolist()
df.drop("Month", axis=0, inplace=True)
df.index.name = ""

df

import re
df.loc["Average high °C (°F)"] = df.loc["Average high °C (°F)"].apply(lambda x: re.findall("(.+)\s\(", x))
df.loc["Average high °C (°F)"] = df.loc["Average high °C (°F)"].apply(lambda x: float(x[0]))

df.loc["Average high °C (°F)"]

# %%
df
# Out:
#                                                              Jan  \
#
# Record high °C (°F)                                  15.5 (59.9)
# Average high °C (°F)                                  3.3 (37.9)
# Daily mean °C (°F)                                    0.6 (33.1)
# Average low °C (°F)                                  −1.9 (28.6)
# Record low °C (°F)                                  −23.1 (−9.6)
# Average rainfall mm (inches)                        42.3 (1.665)
# Average rainy days (≥ 1.0 mm)                               10.0
# Mean monthly sunshine hours                                 46.5
# Source: World Meteorological Organization (UN),...           NaN
#
#                                                               Feb  \
#
# Record high °C (°F)                                   18.7 (65.7)
# Average high °C (°F)                                     5.0 (41)
# Daily mean °C (°F)                                     1.4 (34.5)
# ...

# %%
df.l
# Out:
# Month                                                        Jan  \
# 0
# Record high °C (°F)                                  15.5 (59.9)
# Average high °C (°F)                                  3.3 (37.9)
# Daily mean °C (°F)                                    0.6 (33.1)
# Average low °C (°F)                                  −1.9 (28.6)
# Record low °C (°F)                                  −23.1 (−9.6)
# Average rainfall mm (inches)                        42.3 (1.665)
# Average rainy days (≥ 1.0 mm)                               10.0
# Mean monthly sunshine hours                                 46.5
# Source: World Meteorological Organization (UN),...           NaN
#
# Month                                                         Feb  \
# 0
# Record high °C (°F)                                   18.7 (65.7)
# Average high °C (°F)                                     5.0 (41)
# Daily mean °C (°F)                                     1.4 (34.5)
# ...

# %%
df.index.name
# Out:
# 0
