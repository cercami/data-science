# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("/home/scott/Downloads/puzzle.csv", header=None)
df.head(20)
# Out:
#            0         1
# 0   0.397150  2.113629
# 1   0.397150  2.113629
# 2   0.397150  2.113629
# 3   0.397150  2.113629
# 4   0.397150  2.113629
# 5   0.397150  2.113629
# 6   0.397150  2.113629
# 7   0.397150  2.113629
# 8   0.967562 -0.099246
# 9   0.061841 -1.333110
# 10  0.719915 -0.151519
# 11  0.759443  0.761602
# 12  0.930847 -0.049737
# 13  0.505194 -0.237455
# 14  0.745198  0.408607
# 15 -0.388084  1.991229
# 16  0.132041 -1.257250
# 17  0.715182  0.502910
# 18  1.067695 -2.617924
# 19  0.897974  0.093803

# %%
# why are there duplicates?

#Could it be:

# x y coordinates?
# correlation?
# secret message when scatterplotted?

# %%
df.corr()
# Out:
#           one       two
# one  1.000000 -0.247705
# two -0.247705  1.000000

# %%
df.columns = ['one', 'two']

# %%
df.describe()
# Out:
#                one          two
# count  1024.000000  1024.000000
# mean      0.504729    -0.388165
# std       0.355107     1.499346
# min      -0.925070    -2.837888
# 25%       0.389721    -1.559228
# 50%       0.591392    -1.129903
# 75%       0.746583     0.578621
# max       1.195399     3.096964

# %%
plt.plot(df.one)

# %%
plt.plot(df.two)

# %%
plt.figure()
plt.plot(df.two, color="green")
plt.plot(df.one, color="red");

# Heartbeat?!

# %%
sns.scatterplot(x=df['one'], y=df['two']);

# %%
sns.scatterplot(x=df['two'], y=df['one']);

# %%
# this definitely looks like a world map! but not very pretty
# it misses points in many continents

# The points must represent cities. I deduct this, as the most points are in the developed regions:
# Europe and North America. There are no points where there are no cities, like the middle of Australia.

# Considering what Hopper does, I make an educated guess that these points are actually airports.
