# %% [markdown]
# # String Permutation
#
# ## Problem Statement
#
# Given a string, write a function that uses recursion to output a list of all the possible permutations of that string.
#
# For example, given s='abc' the function should return ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
#
# *Note: If a character is repeated, treat each occurence as distinct, for example an input of 'xxx' would return a list with 6 "versions" of 'xxx'*
#
#
# ## Fill Out Your Solution Below
#
# Let's think about what the steps we need to take here are:

# %%
# WITHOUT RECURSION

s = 'abc'
perms = []
for char1 in s:
    for char2 in s:
        for char3 in s:
            if len(set([char1, char2, char3])) == len(s):
                perms.append(char1 + char2 + char3)

# %%
one = s[0]
two = s[1]
three = s[3]

chars = [one, two, three]

# %%
result
# Out:
# 'abc'

# %%
s[::3]
# Out:
# 'a'

# %%
s[::77]
# Out:
# 'a'

# %%
l = [1, 2, 3]

# %%
l[::-122222]
# Out:
# [3]

# %%
# WORKS FOR FIRST ITERATION, RETURNS ABS


s = "abc"

lista = []
perm = ""
start = s[0]
current_start = None

def permute(s):
    global perm
    
    if (len(perm) == 3) and (len(perm) == len(set(perm)) ):
        print(perm)
        lista.append(perm)
        return
        # run the whole thing again with b as starting point
        #return permute()
    else:
        perm = perm + s[0]
        return permute(s[1:])

    # It means we did the whole loop in one direction
    
    #if start == current_start:
    #    break
    #else:
    #    permute()

# %%
permute(s)
# Out:
# abc

# %%
lista
# Out:
# ['abc']

# %%
s = "abc"

lista = []
perm = ""

start_idx = 0
curr_char_idx = 0

def permute(s):
    global perm
    global start_idx
    global curr_char_idx
    
    if (len(perm) == 3):
        print(perm)
        lista.append(perm)
        # run the whole thing again with b as starting point
        start_idx += 1
        return permute(s)
    else:
        
        # we're at the end of the string and need to grab a char from the front

        perm = s[start_idx] + s[curr_char_idx]
        
        if curr_char_idx == len(s):
            curr_char_idx = 0
        else:
            curr_char_idx += 1

            
        return permute(s)

# %%
permute(s)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-b07e9dee8620> in <module>
# ----> 1 permute(s)
#
# <ipython-input-61-e4c5a74d35db> in permute(s)
#      30
#      31
# ---> 32         return permute(s)
#
# <ipython-input-61-e4c5a74d35db> in permute(s)
#      30
#      31
# ---> 32         return permute(s)
#
# <ipython-input-61-e4c5a74d35db> in permute(s)
#      30
#      31
# ---> 32         return permute(s)
#
# <ipython-input-61-e4c5a74d35db> in permute(s)
#      22         # we're at the end of the string and need to grab a char from the front
#      23
# ---> 24         perm = s[start_idx] + s[curr_char_idx]
#      25
#      26         if curr_char_idx == len(s):
#
# IndexError: string index out of range

# %%
# %debug
# Out:
# > <ipython-input-61-e4c5a74d35db>(24)permute()
#      22         # we're at the end of the string and need to grab a char from the front
#      23
# ---> 24         perm = s[start_idx] + s[curr_char_idx]
#      25
#      26         if curr_char_idx == len(s):
# ipdb>  s[start_idx]

# %%
s[2]
# Out:
# 'c'

# %%
s[0]
# Out:
# 'a'

# %%
#####

# %%
s[2]
# Out:
# 'c'

# %%
s[0]
# Out:
# 'a'

# %%
s[1]
# Out:
# 'b'

# %%
s[1:]
# Out:
# 'bc'

# %%
x = s[1:] + s[0]

# %%
x
# Out:
# 'bca'

# %%
x[2:] + x[1]
# Out:
# 'ac'

# %%
s[::-1]
# Out:
# 'cba'

# %%
def permute(s):
    global i
    global perms
    perms = []
    #perm = ""
    i = 0
    
    def work(new):
        global i
        if len(new) == len(set(s)):
            perms.append(new)
        else:
            i += 1
            return work(new + s[-i])
            
    work("")

# %%
permute("abc")

# %%
perms
# Out:
# ['cba']

# %%
s = "abc"
perms = []

i = 0

def work(new):
    global i
    if len(new) == len(set(s)):
        perms.append(new)
        i += 1
        return work("" + s[::-i])
    else:
        i += 1
        return work(new + s[::-i])

work("")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-21-9be4fcc87e6d>", line 16, in <module>
#     work("")
#   File "<ipython-input-21-9be4fcc87e6d>", line 14, in work
#     return work(new + s[::-i])
#   File "<ipython-input-21-9be4fcc87e6d>", line 11, in work
#     return work("" + s[::-i])
#   File "<ipython-input-21-9be4fcc87e6d>", line 14, in work
#     return work(new + s[::-i])
#   File "<ipython-input-21-9be4fcc87e6d>", line 11, in work
#     return work("" + s[::-i])
#   File "<ipython-input-21-9be4fcc87e6d>", line 14, in work
#     return work(new + s[::-i])
#   File "<ipython-input-21-9be4fcc87e6d>", line 14, in work
#     return work(new + s[::-i])
# ...

# %%
s[::-44]
# Out:
# 'c'

# %%
permute('abc')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-11-0cae1d45451f> in <module>
# ----> 1 permute('abc')
#
# <ipython-input-10-bbbab2b4234c> in permute(s)
#      15             return work(new + s[-i])
#      16
# ---> 17     work("")
#
# <ipython-input-10-bbbab2b4234c> in work(new)
#      12             perms.append(new)
#      13         else:
# ---> 14             i += 1
#      15             return work(new + s[-i])
#      16
#
# UnboundLocalError: local variable 'i' referenced before assignment

# %% [markdown]
# ____
# # Test Your Solution

# %%
"""
RUN THIS CELL TO TEST YOUR SOLUTION.
"""

from nose.tools import assert_equal

class TestPerm(object):
    
    def test(self,solution):
        
        assert_equal(sorted(solution('abc')),sorted(['abc', 'acb', 'bac', 'bca', 'cab', 'cba']))
        assert_equal(sorted(solution('dog')),sorted(['dog', 'dgo', 'odg', 'ogd', 'gdo', 'god']) )
        
        print 'All test cases passed.'
        


# Run Tests
t = TestPerm()
t.test(permute)
# Out:
# All test cases passed.

# %% [markdown]
# ## Good Luck!

# %%
s = "emil"

def rev(s):
    s = list(s)
    
    if s:
        char = s.pop()
        return char + rev(s)
    else:
        # this returns an empty string
        return "".join(s)

# %%
rev(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-fe6a8fc6ab83> in <module>
# ----> 1 rev(s)
#
# <ipython-input-74-adb31ec688e0> in rev(s)
#       6     if s:
#       7         char = s.pop()
# ----> 8         return char + rev(s)
#       9     else:
#      10         return s
#
# <ipython-input-74-adb31ec688e0> in rev(s)
#       6     if s:
#       7         char = s.pop()
# ----> 8         return char + rev(s)
#       9     else:
#      10         return s
#
# <ipython-input-74-adb31ec688e0> in rev(s)
#       6     if s:
#       7         char = s.pop()
# ----> 8         return char + rev(s)
#       9     else:
#      10         return s
#
# <ipython-input-74-adb31ec688e0> in rev(s)
#       6     if s:
#       7         char = s.pop()
# ----> 8         return char + rev(s)
#       9     else:
#      10         return s
#
# TypeError: must be str, not list

# %%
s[:-1]
# Out:
# 'emi'
